# %%
#One line at a time

# %%
import pandas as pd 
import numpy as np

# %%
first_dataset = pd.read_csv("static\IPL_Ball_by_Ball_2008_2022.csv")
second_dataset = pd.read_csv("static\IPL_Matches_2008_2022.csv")

first_dataset.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
second_dataset.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
first_dataset.columns
# Out:
# Index(['ID', 'innings', 'overs', 'ballnumber', 'batter', 'bowler',
#        'non-striker', 'extra_type', 'batsman_run', 'extras_run', 'total_run',
#        'non_boundary', 'isWicketDelivery', 'player_out', 'kind',
#        'fielders_involved', 'BattingTeam'],
#       dtype='object')

# %%
total_runs = first_dataset.groupby(['ID','innings']).sum()['total_run'].add(1).reset_index()

# %%
total_runs
# Out:
#            ID  innings  total_run
# 0      335982        1        223
# 1      335982        2         83
# 2      335983        1        241
# 3      335983        2        208
# 4      335984        1        130
# ...       ...      ...        ...
# 1923  1312198        2        194
# 1924  1312199        1        158
# 1925  1312199        2        162
# 1926  1312200        1        131
# 1927  1312200        2        134
#
# [1928 rows x 3 columns]

# %%
total_runs = total_runs[total_runs['innings']==1]

# %%
match_df = second_dataset.merge(total_runs[['ID','total_run']],left_on='ID',right_on='ID')

# %%
match_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision  ...                  WinningTeam    WonBy Margin  method  \
# 0            bat  ...               Gujarat Titans  Wickets    7.0     NaN
# 1          field  ...             Rajasthan Royals  Wickets    7.0     NaN
# 2          field  ...  Royal Challengers Bangalore     Runs   14.0     NaN
# 3          field  ...               Gujarat Titans  Wickets    7.0     NaN
# 4            bat  ...                 Punjab Kings  Wickets    5.0     NaN
# ..           ...  ...                          ...      ...    ...     ...
# 945          bat  ...        Kolkata Knight Riders  Wickets    5.0     NaN
# 946          bat  ...  Royal Challengers Bangalore  Wickets    5.0     NaN
# 947          bat  ...             Delhi Daredevils  Wickets    9.0     NaN
# 948          bat  ...          Chennai Super Kings     Runs   33.0     NaN
# 949        field  ...        Kolkata Knight Riders     Runs  140.0     NaN
#
#     Player_of_Match                                       Team1Players  \
# 0         HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1        JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2        RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3         DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4     Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..              ...                                                ...
# 945       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2 total_run
# 0       Nitin Menon       131
# 1       Nitin Menon       158
# 2          MA Gough       208
# 3         VK Sharma       189
# 4     NA Patwardhan       158
# ..              ...       ...
# 945     K Hariharan       111
# 946       DJ Harper       166
# 947  GA Pratapkumar       130
# 948      SL Shastri       241
# 949     RE Koertzen       223
#
# [950 rows x 21 columns]

# %%
match_df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64

# %%
match_df['Team1'] = match_df['Team1'].replace('Delhi Daredevils','Delhi Capitals')
match_df['Team2'] = match_df['Team2'].replace('Delhi Daredevils','Delhi Capitals')

match_df['Team1'] = match_df['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team2'] = match_df['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['Team1'] = match_df['Team1'].replace('Kings XI Punjab','Punjab Kings')
match_df['Team2'] = match_df['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
match_df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Sunrisers Hyderabad            108
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Pune Warriors                   23
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: Team1, dtype: int64

# %%
teams = ['Kolkata Knight Riders', 
         'Chennai Super Kings',
         'Punjab Kings', 
         'Rajasthan Royals',
         'Mumbai Indians',
         'Delhi Capitals',
         'Royal Challengers Bangalore',
         'Sunrisers Hyderabad',
         'Lucknow Super Giants',
         'Gujarat Titans'
         ]

# %%
match_df = match_df[match_df['Team1'].isin(teams)]
match_df = match_df[match_df['Team2'].isin(teams)]

# %%
match_df['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    118
# Chennai Super Kings            107
# Delhi Capitals                 106
# Punjab Kings                   103
# Mumbai Indians                 102
# Sunrisers Hyderabad            101
# Kolkata Knight Riders           98
# Rajasthan Royals                85
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Name: Team1, dtype: int64

# %%
match_df.shape
# Out:
# (835, 21)

# %%
match_df = match_df[['ID','City','WinningTeam','total_run', 'Team1', 'Team2']]

# %%
match_df.shape
# Out:
# (835, 6)

# %%
second_innings = match_df.merge(first_dataset,on='ID')
second_innings
# Out:
#              ID       City        Date   Season MatchNumber  \
# 0       1312200  Ahmedabad  2022-05-29     2022       Final
# 1       1312200  Ahmedabad  2022-05-29     2022       Final
# 2       1312200  Ahmedabad  2022-05-29     2022       Final
# 3       1312200  Ahmedabad  2022-05-29     2022       Final
# 4       1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 0                  Rajasthan Royals         Gujarat Titans
# 1                  Rajasthan Royals         Gujarat Titans
# 2                  Rajasthan Royals         Gujarat Titans
# 3                  Rajasthan Royals         Gujarat Titans
# 4                  Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 0       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 3       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 4       Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... extra_type batsman_run extras_run  total_run_y  \
# 0               bat  ...        NaN           0          0            0
# 1               bat  ...    legbyes           0          1            1
# 2               bat  ...        NaN           1          0            1
# 3               bat  ...        NaN           0          0            0
# 4               bat  ...        NaN           0          0            0
# ...             ...  ...        ...         ...        ...          ...
# 225949        field  ...    legbyes           0          1            1
# 225950        field  ...        NaN           1          0            1
# 225951        field  ...        NaN           0          0            0
# 225952        field  ...      wides           0          1            1
# 225953        field  ...        NaN           0          0            0
#
#        non_boundary isWicketDelivery player_out    kind fielders_involved  \
# 0                 0                0        NaN     NaN               NaN
# 1                 0                0        NaN     NaN               NaN
# 2                 0                0        NaN     NaN               NaN
# 3                 0                0        NaN     NaN               NaN
# 4                 0                0        NaN     NaN               NaN
# ...             ...              ...        ...     ...               ...
# 225949            0                0        NaN     NaN               NaN
# 225950            0                0        NaN     NaN               NaN
# 225951            0                0        NaN     NaN               NaN
# 225952            0                0        NaN     NaN               NaN
# 225953            0                1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 37 columns]

# %%
second_innings = second_innings[second_innings['innings']==2]
second_innings.shape
# Out:
# (108910, 37)

# %%
second_innings
# Out:
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# 123                Rajasthan Royals         Gujarat Titans
# 124                Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 120     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 121     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 122     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 123     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 124     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... extra_type batsman_run extras_run  total_run_y  \
# 120             bat  ...        NaN           0          0            0
# 121             bat  ...        NaN           0          0            0
# 122             bat  ...        NaN           1          0            1
# 123             bat  ...        NaN           0          0            0
# 124             bat  ...        NaN           0          0            0
# ...             ...  ...        ...         ...        ...          ...
# 225949        field  ...    legbyes           0          1            1
# 225950        field  ...        NaN           1          0            1
# 225951        field  ...        NaN           0          0            0
# 225952        field  ...      wides           0          1            1
# 225953        field  ...        NaN           0          0            0
#
#        non_boundary isWicketDelivery player_out    kind fielders_involved  \
# 120               0                0        NaN     NaN               NaN
# 121               0                0        NaN     NaN               NaN
# 122               0                0        NaN     NaN               NaN
# 123               0                0        NaN     NaN               NaN
# 124               0                0        NaN     NaN               NaN
# ...             ...              ...        ...     ...               ...
# 225949            0                0        NaN     NaN               NaN
# 225950            0                0        NaN     NaN               NaN
# 225951            0                0        NaN     NaN               NaN
# 225952            0                0        NaN     NaN               NaN
# 225953            0                1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 120                  Gujarat Titans
# 121                  Gujarat Titans
# 122                  Gujarat Titans
# 123                  Gujarat Titans
# 124                  Gujarat Titans
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [108910 rows x 37 columns]

# %%
second_innings['Team1'] = second_innings['Team1'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['Team2'] = second_innings['Team2'].replace('Delhi Daredevils','Delhi Capitals')

second_innings['Team1'] = second_innings['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['Team2'] = second_innings['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['Team1'] = second_innings['Team1'].replace('Kings XI Punjab','Punjab Kings')
second_innings['Team2'] = second_innings['Team2'].replace('Kings XI Punjab','Punjab Kings')
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\340332489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Delhi Daredevils','Delhi Capitals')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\340332489.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Delhi Daredevils','Delhi Capitals')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\340332489.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Deccan Chargers','Sunrisers Hyderabad')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\340332489.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Deccan Chargers','Sunrisers Hyderabad')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\340332489.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team1'] = second_innings['Team1'].replace('Kings XI Punjab','Punjab Kings')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\340332489.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['Team2'] = second_innings['Team2'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings['Team1'].value_counts()
# Out:
# Royal Challengers Bangalore    14182
# Chennai Super Kings            13142
# Mumbai Indians                 13102
# Delhi Capitals                 12870
# Punjab Kings                   12613
# Sunrisers Hyderabad            12469
# Kolkata Knight Riders          11826
# Rajasthan Royals               10194
# Pune Warriors                   2651
# Gujarat Lions                   1800
# Lucknow Super Giants             968
# Rising Pune Supergiants          809
# Gujarat Titans                   790
# Rising Pune Supergiant           776
# Kochi Tuskers Kerala             718
# Name: Team1, dtype: int64

# %%
second_innings.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'total_run_x', 'innings', 'overs',
#        'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run_y', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam'],
#       dtype='object')

# %%
second_innings.shape
# Out:
# (108910, 37)

# %%
# Function to determine the bowling team
def determine_bowling_team(row):
    if row['BattingTeam'] == row['Team1']:
        return row['Team2']
    else:
        return row['Team1']

# Create the new 'BowlingTeam' column
second_innings['BowlingTeam'] = second_innings.apply(determine_bowling_team, axis=1)
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1658040854.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings.apply(determine_bowling_team, axis=1)

# %%
second_innings.tail(103)
# Out:
#             ID        City        Date   Season MatchNumber  \
# 225727  335983  Chandigarh  2008-04-19  2007/08           2
# 225728  335983  Chandigarh  2008-04-19  2007/08           2
# 225853  335982   Bangalore  2008-04-18  2007/08           1
# 225854  335982   Bangalore  2008-04-18  2007/08           1
# 225855  335982   Bangalore  2008-04-18  2007/08           1
# ...        ...         ...         ...      ...         ...
# 225949  335982   Bangalore  2008-04-18  2007/08           1
# 225950  335982   Bangalore  2008-04-18  2007/08           1
# 225951  335982   Bangalore  2008-04-18  2007/08           1
# 225952  335982   Bangalore  2008-04-18  2007/08           1
# 225953  335982   Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 225727                 Punjab Kings    Chennai Super Kings
# 225728                 Punjab Kings    Chennai Super Kings
# 225853  Royal Challengers Bangalore  Kolkata Knight Riders
# 225854  Royal Challengers Bangalore  Kolkata Knight Riders
# 225855  Royal Challengers Bangalore  Kolkata Knight Riders
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                              Venue  \
# 225727  Punjab Cricket Association Stadium, Mohali
# 225728  Punjab Cricket Association Stadium, Mohali
# 225853                       M Chinnaswamy Stadium
# 225854                       M Chinnaswamy Stadium
# 225855                       M Chinnaswamy Stadium
# ...                                            ...
# 225949                       M Chinnaswamy Stadium
# 225950                       M Chinnaswamy Stadium
# 225951                       M Chinnaswamy Stadium
# 225952                       M Chinnaswamy Stadium
# 225953                       M Chinnaswamy Stadium
#
#                          TossWinner TossDecision  ... batsman_run extras_run  \
# 225727          Chennai Super Kings          bat  ...           1          0
# 225728          Chennai Super Kings          bat  ...           0          0
# 225853  Royal Challengers Bangalore        field  ...           1          0
# 225854  Royal Challengers Bangalore        field  ...           0          1
# 225855  Royal Challengers Bangalore        field  ...           0          0
# ...                             ...          ...  ...         ...        ...
# 225949  Royal Challengers Bangalore        field  ...           0          1
# 225950  Royal Challengers Bangalore        field  ...           1          0
# 225951  Royal Challengers Bangalore        field  ...           0          0
# 225952  Royal Challengers Bangalore        field  ...           0          1
# 225953  Royal Challengers Bangalore        field  ...           0          0
#
#        total_run_y  non_boundary isWicketDelivery player_out    kind  \
# 225727           1             0                0        NaN     NaN
# 225728           0             0                0        NaN     NaN
# 225853           1             0                0        NaN     NaN
# 225854           1             0                0        NaN     NaN
# 225855           0             0                0        NaN     NaN
# ...            ...           ...              ...        ...     ...
# 225949           1             0                0        NaN     NaN
# 225950           1             0                0        NaN     NaN
# 225951           0             0                0        NaN     NaN
# 225952           1             0                0        NaN     NaN
# 225953           0             0                1   SB Joshi  caught
#
#        fielders_involved                  BattingTeam            BowlingTeam
# 225727               NaN              Kings XI Punjab           Punjab Kings
# 225728               NaN              Kings XI Punjab           Punjab Kings
# 225853               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225854               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225855               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# ...                  ...                          ...                    ...
# 225949               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953       BB McCullum  Royal Challengers Bangalore  Kolkata Knight Riders
#
# [103 rows x 38 columns]

# %%
second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Delhi Daredevils','Delhi Capitals')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Delhi Daredevils','Delhi Capitals')

second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')

second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')
second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Kings XI Punjab','Punjab Kings')
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1361729818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Delhi Daredevils','Delhi Capitals')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1361729818.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Delhi Daredevils','Delhi Capitals')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1361729818.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1361729818.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Deccan Chargers','Sunrisers Hyderabad')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1361729818.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BattingTeam'] = second_innings['BattingTeam'].replace('Kings XI Punjab','Punjab Kings')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1361729818.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['BowlingTeam'] = second_innings['BowlingTeam'].replace('Kings XI Punjab','Punjab Kings')

# %%
second_innings
# Out:
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# 123                Rajasthan Royals         Gujarat Titans
# 124                Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 120     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 121     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 122     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 123     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 124     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... batsman_run extras_run total_run_y  non_boundary  \
# 120             bat  ...           0          0           0             0
# 121             bat  ...           0          0           0             0
# 122             bat  ...           1          0           1             0
# 123             bat  ...           0          0           0             0
# 124             bat  ...           0          0           0             0
# ...             ...  ...         ...        ...         ...           ...
# 225949        field  ...           0          1           1             0
# 225950        field  ...           1          0           1             0
# 225951        field  ...           0          0           0             0
# 225952        field  ...           0          1           1             0
# 225953        field  ...           0          0           0             0
#
#        isWicketDelivery player_out    kind fielders_involved  \
# 120                   0        NaN     NaN               NaN
# 121                   0        NaN     NaN               NaN
# 122                   0        NaN     NaN               NaN
# 123                   0        NaN     NaN               NaN
# 124                   0        NaN     NaN               NaN
# ...                 ...        ...     ...               ...
# 225949                0        NaN     NaN               NaN
# 225950                0        NaN     NaN               NaN
# 225951                0        NaN     NaN               NaN
# 225952                0        NaN     NaN               NaN
# 225953                1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam            BowlingTeam
# 120                  Gujarat Titans       Rajasthan Royals
# 121                  Gujarat Titans       Rajasthan Royals
# 122                  Gujarat Titans       Rajasthan Royals
# 123                  Gujarat Titans       Rajasthan Royals
# 124                  Gujarat Titans       Rajasthan Royals
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
# [108910 rows x 38 columns]

# %%
second_innings['BowlingTeam'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Rising Pune Supergiant',
#        'Gujarat Lions', 'Rising Pune Supergiants', 'Pune Warriors',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
second_innings['current_Score'] = second_innings.groupby('ID').cumsum()['total_run_y']
second_innings
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\3076402150.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['current_Score'] = second_innings.groupby('ID').cumsum()['total_run_y']
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# 123                Rajasthan Royals         Gujarat Titans
# 124                Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 120     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 121     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 122     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 123     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 124     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... extras_run total_run_y non_boundary  \
# 120             bat  ...          0           0            0
# 121             bat  ...          0           0            0
# 122             bat  ...          0           1            0
# 123             bat  ...          0           0            0
# 124             bat  ...          0           0            0
# ...             ...  ...        ...         ...          ...
# 225949        field  ...          1           1            0
# 225950        field  ...          0           1            0
# 225951        field  ...          0           0            0
# 225952        field  ...          1           1            0
# 225953        field  ...          0           0            0
#
#         isWicketDelivery player_out    kind fielders_involved  \
# 120                    0        NaN     NaN               NaN
# 121                    0        NaN     NaN               NaN
# 122                    0        NaN     NaN               NaN
# 123                    0        NaN     NaN               NaN
# 124                    0        NaN     NaN               NaN
# ...                  ...        ...     ...               ...
# 225949                 0        NaN     NaN               NaN
# 225950                 0        NaN     NaN               NaN
# 225951                 0        NaN     NaN               NaN
# 225952                 0        NaN     NaN               NaN
# 225953                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam            BowlingTeam current_Score
# 120                  Gujarat Titans       Rajasthan Royals             0
# 121                  Gujarat Titans       Rajasthan Royals             0
# 122                  Gujarat Titans       Rajasthan Royals             1
# 123                  Gujarat Titans       Rajasthan Royals             1
# 124                  Gujarat Titans       Rajasthan Royals             1
# ...                             ...                    ...           ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders            80
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders            81
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders            81
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders            82
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders            82
#
# [108910 rows x 39 columns]

# %%
second_innings['runs_left'] = second_innings['total_run_x'] - second_innings['current_Score']
second_innings
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\802083827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['runs_left'] = second_innings['total_run_x'] - second_innings['current_Score']
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# 123                Rajasthan Royals         Gujarat Titans
# 124                Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 120     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 121     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 122     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 123     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 124     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... total_run_y non_boundary isWicketDelivery  \
# 120             bat  ...           0            0                0
# 121             bat  ...           0            0                0
# 122             bat  ...           1            0                0
# 123             bat  ...           0            0                0
# 124             bat  ...           0            0                0
# ...             ...  ...         ...          ...              ...
# 225949        field  ...           1            0                0
# 225950        field  ...           1            0                0
# 225951        field  ...           0            0                0
# 225952        field  ...           1            0                0
# 225953        field  ...           0            0                1
#
#         player_out    kind fielders_involved                  BattingTeam  \
# 120            NaN     NaN               NaN               Gujarat Titans
# 121            NaN     NaN               NaN               Gujarat Titans
# 122            NaN     NaN               NaN               Gujarat Titans
# 123            NaN     NaN               NaN               Gujarat Titans
# 124            NaN     NaN               NaN               Gujarat Titans
# ...            ...     ...               ...                          ...
# 225949         NaN     NaN               NaN  Royal Challengers Bangalore
# 225950         NaN     NaN               NaN  Royal Challengers Bangalore
# 225951         NaN     NaN               NaN  Royal Challengers Bangalore
# 225952         NaN     NaN               NaN  Royal Challengers Bangalore
# 225953    SB Joshi  caught       BB McCullum  Royal Challengers Bangalore
#
#                   BowlingTeam current_Score runs_left
# 120          Rajasthan Royals             0       131
# 121          Rajasthan Royals             0       131
# 122          Rajasthan Royals             1       130
# 123          Rajasthan Royals             1       130
# 124          Rajasthan Royals             1       130
# ...                       ...           ...       ...
# 225949  Kolkata Knight Riders            80       143
# 225950  Kolkata Knight Riders            81       142
# 225951  Kolkata Knight Riders            81       142
# 225952  Kolkata Knight Riders            82       141
# 225953  Kolkata Knight Riders            82       141
#
# [108910 rows x 40 columns]

# %%
second_innings['balls_left'] = 126 - (second_innings['overs']*6 +second_innings['ballnumber'])
second_innings
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\2820591732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['balls_left'] = 126 - (second_innings['overs']*6 +second_innings['ballnumber'])
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# 123                Rajasthan Royals         Gujarat Titans
# 124                Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 120     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 121     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 122     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 123     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 124     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... non_boundary isWicketDelivery player_out    kind  \
# 120             bat  ...            0                0        NaN     NaN
# 121             bat  ...            0                0        NaN     NaN
# 122             bat  ...            0                0        NaN     NaN
# 123             bat  ...            0                0        NaN     NaN
# 124             bat  ...            0                0        NaN     NaN
# ...             ...  ...          ...              ...        ...     ...
# 225949        field  ...            0                0        NaN     NaN
# 225950        field  ...            0                0        NaN     NaN
# 225951        field  ...            0                0        NaN     NaN
# 225952        field  ...            0                0        NaN     NaN
# 225953        field  ...            0                1   SB Joshi  caught
#
#        fielders_involved                  BattingTeam            BowlingTeam  \
# 120                  NaN               Gujarat Titans       Rajasthan Royals
# 121                  NaN               Gujarat Titans       Rajasthan Royals
# 122                  NaN               Gujarat Titans       Rajasthan Royals
# 123                  NaN               Gujarat Titans       Rajasthan Royals
# 124                  NaN               Gujarat Titans       Rajasthan Royals
# ...                  ...                          ...                    ...
# 225949               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952               NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953       BB McCullum  Royal Challengers Bangalore  Kolkata Knight Riders
#
#        current_Score runs_left balls_left
# 120                0       131        125
# 121                0       131        124
# 122                1       130        123
# 123                1       130        122
# 124                1       130        121
# ...              ...       ...        ...
# 225949            80       143         37
# 225950            81       142         36
# 225951            81       142         35
# 225952            82       141         35
# 225953            82       141         34
#
# [108910 rows x 41 columns]

# %%
second_innings.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'total_run_x', 'innings', 'overs',
#        'ballnumber', 'batter', 'bowler', 'non-striker', 'extra_type',
#        'batsman_run', 'extras_run', 'total_run_y', 'non_boundary',
#        'isWicketDelivery', 'player_out', 'kind', 'fielders_involved',
#        'BattingTeam', 'BowlingTeam', 'current_Score', 'runs_left',
#        'balls_left'],
#       dtype='object')

# %%
# Select the columns of interest
columns_to_check = ['current_Score', 'runs_left', 'balls_left']

# Check how many values in each column are negative
negative_counts = second_innings[columns_to_check].lt(0).sum()

# Display the counts
print("Number of negative values in each column:")
print(negative_counts)
# Out:
# Number of negative values in each column:
# current_Score      0
# runs_left        306
# balls_left         0
# dtype: int64

# %%
second_innings['player_out'] = second_innings['player_out'].fillna("0")
second_innings['player_out'] = second_innings['player_out'].apply(lambda x:x if x=="0" else "1")
second_innings['player_out'] = second_innings['player_out'].astype('int')
wickets = second_innings.groupby('ID').cumsum()['player_out']
second_innings['wickets_remaining'] = 10-wickets
second_innings
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1997531377.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].fillna("0")
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1997531377.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].apply(lambda x:x if x=="0" else "1")
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1997531377.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['player_out'] = second_innings['player_out'].astype('int')
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1997531377.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['wickets_remaining'] = 10-wickets
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# 123                Rajasthan Royals         Gujarat Titans
# 124                Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 120     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 121     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 122     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 123     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 124     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... isWicketDelivery player_out    kind  \
# 120             bat  ...                0          0     NaN
# 121             bat  ...                0          0     NaN
# 122             bat  ...                0          0     NaN
# 123             bat  ...                0          0     NaN
# 124             bat  ...                0          0     NaN
# ...             ...  ...              ...        ...     ...
# 225949        field  ...                0          0     NaN
# 225950        field  ...                0          0     NaN
# 225951        field  ...                0          0     NaN
# 225952        field  ...                0          0     NaN
# 225953        field  ...                1          1  caught
#
#         fielders_involved                  BattingTeam            BowlingTeam  \
# 120                   NaN               Gujarat Titans       Rajasthan Royals
# 121                   NaN               Gujarat Titans       Rajasthan Royals
# 122                   NaN               Gujarat Titans       Rajasthan Royals
# 123                   NaN               Gujarat Titans       Rajasthan Royals
# 124                   NaN               Gujarat Titans       Rajasthan Royals
# ...                   ...                          ...                    ...
# 225949                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952                NaN  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953        BB McCullum  Royal Challengers Bangalore  Kolkata Knight Riders
#
#        current_Score runs_left balls_left wickets_remaining
# 120                0       131        125                10
# 121                0       131        124                10
# 122                1       130        123                10
# 123                1       130        122                10
# 124                1       130        121                10
# ...              ...       ...        ...               ...
# 225949            80       143         37                 1
# 225950            81       142         36                 1
# 225951            81       142         35                 1
# 225952            82       141         35                 1
# 225953            82       141         34                 0
#
# [108910 rows x 42 columns]

# %%
second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
second_innings
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1691903609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['crr'] = round((second_innings['current_Score']*6)/(120 - second_innings['balls_left']),2)
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\1691903609.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['rrr'] = round((second_innings['runs_left']*6)/(second_innings['balls_left']),2)
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# 123                Rajasthan Royals         Gujarat Titans
# 124                Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 120     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 121     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 122     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 123     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 124     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ...    kind fielders_involved  \
# 120             bat  ...     NaN               NaN
# 121             bat  ...     NaN               NaN
# 122             bat  ...     NaN               NaN
# 123             bat  ...     NaN               NaN
# 124             bat  ...     NaN               NaN
# ...             ...  ...     ...               ...
# 225949        field  ...     NaN               NaN
# 225950        field  ...     NaN               NaN
# 225951        field  ...     NaN               NaN
# 225952        field  ...     NaN               NaN
# 225953        field  ...  caught       BB McCullum
#
#                         BattingTeam            BowlingTeam current_Score  \
# 120                  Gujarat Titans       Rajasthan Royals             0
# 121                  Gujarat Titans       Rajasthan Royals             0
# 122                  Gujarat Titans       Rajasthan Royals             1
# 123                  Gujarat Titans       Rajasthan Royals             1
# 124                  Gujarat Titans       Rajasthan Royals             1
# ...                             ...                    ...           ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders            80
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders            81
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders            81
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders            82
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders            82
#
#        runs_left balls_left wickets_remaining   crr    rrr
# 120          131        125                10 -0.00   6.29
# 121          131        124                10 -0.00   6.34
# 122          130        123                10 -2.00   6.34
# 123          130        122                10 -3.00   6.39
# 124          130        121                10 -6.00   6.45
# ...          ...        ...               ...   ...    ...
# 225949       143         37                 1  5.78  23.19
# 225950       142         36                 1  5.79  23.67
# 225951       142         35                 1  5.72  24.34
# 225952       141         35                 1  5.79  24.17
# 225953       141         34                 0  5.72  24.88
#
# [108910 rows x 44 columns]

# %%
def winner(team):
    return 1 if team['BattingTeam'] == team['WinningTeam'] else 0

# %%
second_innings['results'] = second_innings.apply(winner,axis=1)
second_innings
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\3111665595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   second_innings['results'] = second_innings.apply(winner,axis=1)
#              ID       City        Date   Season MatchNumber  \
# 120     1312200  Ahmedabad  2022-05-29     2022       Final
# 121     1312200  Ahmedabad  2022-05-29     2022       Final
# 122     1312200  Ahmedabad  2022-05-29     2022       Final
# 123     1312200  Ahmedabad  2022-05-29     2022       Final
# 124     1312200  Ahmedabad  2022-05-29     2022       Final
# ...         ...        ...         ...      ...         ...
# 225949   335982  Bangalore  2008-04-18  2007/08           1
# 225950   335982  Bangalore  2008-04-18  2007/08           1
# 225951   335982  Bangalore  2008-04-18  2007/08           1
# 225952   335982  Bangalore  2008-04-18  2007/08           1
# 225953   335982  Bangalore  2008-04-18  2007/08           1
#
#                               Team1                  Team2  \
# 120                Rajasthan Royals         Gujarat Titans
# 121                Rajasthan Royals         Gujarat Titans
# 122                Rajasthan Royals         Gujarat Titans
# 123                Rajasthan Royals         Gujarat Titans
# 124                Rajasthan Royals         Gujarat Titans
# ...                             ...                    ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                                    Venue                   TossWinner  \
# 120     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 121     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 122     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 123     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 124     Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# ...                                  ...                          ...
# 225949             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225950             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225951             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225952             M Chinnaswamy Stadium  Royal Challengers Bangalore
# 225953             M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#        TossDecision  ... fielders_involved                  BattingTeam  \
# 120             bat  ...               NaN               Gujarat Titans
# 121             bat  ...               NaN               Gujarat Titans
# 122             bat  ...               NaN               Gujarat Titans
# 123             bat  ...               NaN               Gujarat Titans
# 124             bat  ...               NaN               Gujarat Titans
# ...             ...  ...               ...                          ...
# 225949        field  ...               NaN  Royal Challengers Bangalore
# 225950        field  ...               NaN  Royal Challengers Bangalore
# 225951        field  ...               NaN  Royal Challengers Bangalore
# 225952        field  ...               NaN  Royal Challengers Bangalore
# 225953        field  ...       BB McCullum  Royal Challengers Bangalore
#
#                   BowlingTeam  current_Score runs_left balls_left  \
# 120          Rajasthan Royals              0       131        125
# 121          Rajasthan Royals              0       131        124
# 122          Rajasthan Royals              1       130        123
# 123          Rajasthan Royals              1       130        122
# 124          Rajasthan Royals              1       130        121
# ...                       ...            ...       ...        ...
# 225949  Kolkata Knight Riders             80       143         37
# 225950  Kolkata Knight Riders             81       142         36
# 225951  Kolkata Knight Riders             81       142         35
# 225952  Kolkata Knight Riders             82       141         35
# 225953  Kolkata Knight Riders             82       141         34
#
#        wickets_remaining   crr    rrr results
# 120                   10 -0.00   6.29       1
# 121                   10 -0.00   6.34       1
# 122                   10 -2.00   6.34       1
# 123                   10 -3.00   6.39       1
# 124                   10 -6.00   6.45       1
# ...                  ...   ...    ...     ...
# 225949                 1  5.78  23.19       0
# 225950                 1  5.79  23.67       0
# 225951                 1  5.72  24.34       0
# 225952                 1  5.79  24.17       0
# 225953                 0  5.72  24.88       0
#
# [108910 rows x 45 columns]

# %%
required_data = second_innings[['BattingTeam','BowlingTeam','City','runs_left','balls_left','wickets_remaining','total_run_x','crr','rrr','results']]
required_data
# Out:
#                         BattingTeam            BowlingTeam       City  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 122                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 123                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 124                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#         runs_left  balls_left  wickets_remaining  total_run_x   crr    rrr  \
# 120           131         125                 10          131 -0.00   6.29
# 121           131         124                 10          131 -0.00   6.34
# 122           130         123                 10          131 -2.00   6.34
# 123           130         122                 10          131 -3.00   6.39
# 124           130         121                 10          131 -6.00   6.45
# ...           ...         ...                ...          ...   ...    ...
# 225949        143          37                  1          223  5.78  23.19
# 225950        142          36                  1          223  5.79  23.67
# 225951        142          35                  1          223  5.72  24.34
# 225952        141          35                  1          223  5.79  24.17
# 225953        141          34                  0          223  5.72  24.88
#
#         results
# 120           1
# 121           1
# 122           1
# 123           1
# 124           1
# ...         ...
# 225949        0
# 225950        0
# 225951        0
# 225952        0
# 225953        0
#
# [108910 rows x 10 columns]

# %%
required_data = required_data.replace([np.inf, -np.inf], np.nan)
required_data = required_data.dropna()

# %%
required_data = required_data[required_data['crr'] >= 0]

# %%
columns_to_check = ['runs_left', 'balls_left', 'wickets_remaining', 'total_run_x', 'crr', 'rrr', 'results']

required_data = required_data[~(required_data[columns_to_check] < 0).any(axis=1)]

# %%
required_data.head()
# Out:
#         BattingTeam       BowlingTeam       City  runs_left  balls_left  \
# 120  Gujarat Titans  Rajasthan Royals  Ahmedabad        131         125
# 121  Gujarat Titans  Rajasthan Royals  Ahmedabad        131         124
# 126  Gujarat Titans  Rajasthan Royals  Ahmedabad        126         119
# 127  Gujarat Titans  Rajasthan Royals  Ahmedabad        122         118
# 128  Gujarat Titans  Rajasthan Royals  Ahmedabad        122         117
#
#      wickets_remaining  total_run_x   crr   rrr  results
# 120                 10          131  -0.0  6.29        1
# 121                 10          131  -0.0  6.34        1
# 126                 10          131  30.0  6.35        1
# 127                 10          131  27.0  6.20        1
# 128                 10          131  18.0  6.26        1

# %%
# Assuming your DataFrame is named 'df'
required_data.rename(columns={'BattingTeam': 'batting_team', 'BowlingTeam': 'bowling_team', 'City': 'city'}, inplace=True)
required_data
# Out:
# C:\Users\Sandesh Pargaonkar\AppData\Local\Temp\ipykernel_12376\545772493.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   required_data.rename(columns={'BattingTeam': 'batting_team', 'BowlingTeam': 'bowling_team', 'City': 'city'}, inplace=True)
#                        batting_team           bowling_team       city  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 126                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 127                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 128                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 225949  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 225950  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 225951  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 225952  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 225953  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#         runs_left  balls_left  wickets_remaining  total_run_x    crr    rrr  \
# 120           131         125                 10          131  -0.00   6.29
# 121           131         124                 10          131  -0.00   6.34
# 126           126         119                 10          131  30.00   6.35
# 127           122         118                 10          131  27.00   6.20
# 128           122         117                 10          131  18.00   6.26
# ...           ...         ...                ...          ...    ...    ...
# 225949        143          37                  1          223   5.78  23.19
# 225950        142          36                  1          223   5.79  23.67
# 225951        142          35                  1          223   5.72  24.34
# 225952        141          35                  1          223   5.79  24.17
# 225953        141          34                  0          223   5.72  24.88
#
#         results
# 120           1
# 121           1
# 126           1
# 127           1
# 128           1
# ...         ...
# 225949        0
# 225950        0
# 225951        0
# 225952        0
# 225953        0
#
# [98341 rows x 10 columns]

# %%
numeric = required_data[['runs_left', 'balls_left', 'wickets_remaining', 'total_run_x', 'crr', 'rrr', 'results']]
has_infinite_values = np.any(np.isinf(numeric))

# Check for negative values in the entire DataFrame
has_negative_values = (numeric < 0).any().any()

# Check for null values in the entire DataFrame
has_null_values = numeric.isnull().any().any()

# Display the results
print(f"Has Infinite Values: {has_infinite_values}")
print(f"Has Negative Values: {has_negative_values}")
print(f"Has Null Values: {has_null_values}")
# Out:
# Has Infinite Values: False
# Has Negative Values: False
# Has Null Values: False

# %%
required_data.to_csv("csv2008-22.csv", index=False)

# %%
from sklearn.model_selection import train_test_split

# %%
x = required_data.iloc[:, :-1]
y = required_data.iloc[:,-1]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=100)
x_train.head()
# Out:
#                  batting_team                 bowling_team        city  \
# 55831     Chennai Super Kings        Kolkata Knight Riders     Chennai
# 164545    Chennai Super Kings  Royal Challengers Bangalore     Chennai
# 224293         Mumbai Indians          Chennai Super Kings     Chennai
# 71944     Sunrisers Hyderabad                 Punjab Kings  Chandigarh
# 18075   Kolkata Knight Riders          Chennai Super Kings       Dubai
#
#         runs_left  balls_left  wickets_remaining  total_run_x    crr    rrr
# 55831          40          53                  8          109   6.18   4.53
# 164545         55          26                  7          206   9.64  12.69
# 224293         79          41                  6          209   9.87  11.56
# 71944          65          30                  6          194   8.60  13.00
# 18075         137          88                 10          193  10.50   9.34

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
],
remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8304319531440657

# %%
pipe.predict_proba(x_test)[0]
# Out:
# array([0.99626214, 0.00373786])

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
from sklearn.ensemble import RandomForestClassifier

ra_pipe = Pipeline([
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

ra_pipe.fit(x_train,y_train)

ra_y_pred = ra_pipe.predict(x_test)

accuracy_score(y_test,ra_y_pred)
# Out:
# 0.9986984462702351

# %%
import pickle
pickle.dump(ra_pipe,open('ra_pipe.pkl','wb'))

# %%
required_data.head(2)
# Out:
#        batting_team      bowling_team       city  runs_left  balls_left  \
# 120  Gujarat Titans  Rajasthan Royals  Ahmedabad        131         125
# 121  Gujarat Titans  Rajasthan Royals  Ahmedabad        131         124
#
#      wickets_remaining  total_run_x  crr   rrr  results
# 120                 10          131 -0.0  6.29        1
# 121                 10          131 -0.0  6.34        1

# %%
data = pd.read_csv('csv2023.csv')
data.rename(columns={'max_total_run_x': 'total_run_x'}, inplace=True)
data.head(2)
# Out:
#      batting_team         bowling_team       city  runs_left  balls_left  \
# 0  Gujarat Titans  Chennai Super Kings  Ahmedabad        179         125
# 1  Gujarat Titans  Chennai Super Kings  Ahmedabad        179         124
#
#    wickets_remaining  total_run_x  crr   rrr  results
# 0                 10          179 -0.0  8.59        1
# 1                 10          179 -0.0  8.66        1

# %%
df = pd.concat([required_data, data], ignore_index=True)
df
# Out:
#                batting_team      bowling_team       city  runs_left  \
# 0            Gujarat Titans  Rajasthan Royals  Ahmedabad        131
# 1            Gujarat Titans  Rajasthan Royals  Ahmedabad        131
# 2            Gujarat Titans  Rajasthan Royals  Ahmedabad        126
# 3            Gujarat Titans  Rajasthan Royals  Ahmedabad        122
# 4            Gujarat Titans  Rajasthan Royals  Ahmedabad        122
# ...                     ...               ...        ...        ...
# 106599  Chennai Super Kings    Gujarat Titans  Ahmedabad         56
# 106600  Chennai Super Kings    Gujarat Titans  Ahmedabad         55
# 106601  Chennai Super Kings    Gujarat Titans  Ahmedabad         54
# 106602  Chennai Super Kings    Gujarat Titans  Ahmedabad         48
# 106603  Chennai Super Kings    Gujarat Titans  Ahmedabad         44
#
#         balls_left  wickets_remaining  total_run_x    crr   rrr  results
# 0              125                 10          131  -0.00  6.29        1
# 1              124                 10          131  -0.00  6.34        1
# 2              119                 10          131  30.00  6.35        1
# 3              118                 10          131  27.00  6.20        1
# 4              117                 10          131  18.00  6.26        1
# ...            ...                ...          ...    ...   ...      ...
# 106599          40                  5          215  11.92  8.40        1
# 106600          39                  5          215  11.85  8.46        1
# 106601          38                  5          215  11.78  8.53        1
# 106602          37                  5          215  12.07  7.78        1
# 106603          36                  5          215  12.21  7.33        1
#
# [106604 rows x 10 columns]

# %%
df.to_csv('dataset.csv')

# %%
x = df.iloc[:, :-1]
y = df.iloc[:,-1]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=100)
x_train.head()
# Out:
#                       batting_team                 bowling_team        city  \
# 83100        Kolkata Knight Riders               Delhi Capitals       Delhi
# 45186             Rajasthan Royals          Sunrisers Hyderabad      Mumbai
# 63509               Delhi Capitals               Delhi Capitals        Pune
# 72577  Royal Challengers Bangalore                 Punjab Kings  Dharamsala
# 33729                Gujarat Lions  Royal Challengers Bangalore   Bangalore
#
#        runs_left  balls_left  wickets_remaining  total_run_x    crr    rrr
# 83100         63          25                  4          178   7.26  15.12
# 45186        125          61                  7          202   7.83  12.30
# 63509        117          98                  8          163  12.55   7.16
# 72577        178          77                  6          233   7.67  13.87
# 33729         54          70                  8          135   9.72   4.63

# %%
from sklearn.ensemble import RandomForestClassifier

ra_pipe = Pipeline([
    ('step1',trf),
    ('step2',RandomForestClassifier())
])

ra_pipe.fit(x_train,y_train)

ra_y_pred = ra_pipe.predict(x_test)

accuracy_score(y_test,ra_y_pred)
# Out:
# 0.9990994709391767

# %%
import pickle
pickle.dump(ra_pipe,open('ra_pipe.pkl','wb'))
